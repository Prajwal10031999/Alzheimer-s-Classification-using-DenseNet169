# %% [markdown]
# ### IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ### IMPORT / VIEWING / PREPROCESSING DATASET

# %% [markdown]
# > `DATA AUGMENTATION`

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 128)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 128)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Demetia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [00:17<00:00,  3.44s/it]

# %% [markdown]
# ### MODEL BUILDING

# %%
# Model Initialization

base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51879936/51877672 [==============================] - 1s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet169 (Functional)     (None, 7, 7, 1664)        12642880
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 1664)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 81536)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 81536)             326144
# _________________________________________________________________
# dense (Dense)                (None, 2048)              166987776
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# activation (Activation)      (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 182,071,364
# Trainable params: 169,259,268
# Non-trainable params: 12,812,096
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)

# %%
# Defining Callbacks

filepath = './best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 500,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/500
# 33/33 [==============================] - ETA: 0s - loss: 1.3226 - auc: 0.7894
# Epoch 00001: val_auc improved from -inf to 0.68573, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 72s 2s/step - loss: 1.3226 - auc: 0.7894 - val_loss: 5.2772 - val_auc: 0.6857
# Epoch 2/500
# 33/33 [==============================] - ETA: 0s - loss: 1.0816 - auc: 0.8324
# Epoch 00002: val_auc improved from 0.68573 to 0.73006, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 76s 2s/step - loss: 1.0816 - auc: 0.8324 - val_loss: 2.5155 - val_auc: 0.7301
# Epoch 3/500
# 33/33 [==============================] - ETA: 0s - loss: 0.9912 - auc: 0.8498
# Epoch 00003: val_auc did not improve from 0.73006
# 33/33 [==============================] - 54s 2s/step - loss: 0.9912 - auc: 0.8498 - val_loss: 2.3908 - val_auc: 0.7253
# Epoch 4/500
# 33/33 [==============================] - ETA: 0s - loss: 0.9562 - auc: 0.8560
# Epoch 00004: val_auc improved from 0.73006 to 0.75874, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 63s 2s/step - loss: 0.9562 - auc: 0.8560 - val_loss: 1.6553 - val_auc: 0.7587
# Epoch 5/500
# 33/33 [==============================] - ETA: 0s - loss: 0.9203 - auc: 0.8655
# Epoch 00005: val_auc improved from 0.75874 to 0.76947, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 63s 2s/step - loss: 0.9203 - auc: 0.8655 - val_loss: 1.7151 - val_auc: 0.7695
# Epoch 6/500
# 33/33 [==============================] - ETA: 0s - loss: 0.8456 - auc: 0.8792
# Epoch 00006: val_auc did not improve from 0.76947
# 33/33 [==============================] - 56s 2s/step - loss: 0.8456 - auc: 0.8792 - val_loss: 1.5530 - val_auc: 0.7665
# Epoch 7/500
# 33/33 [==============================] - ETA: 0s - loss: 0.8321 - auc: 0.8801
# Epoch 00007: val_auc did not improve from 0.76947
# 33/33 [==============================] - 54s 2s/step - loss: 0.8321 - auc: 0.8801 - val_loss: 1.3648 - val_auc: 0.7565
# Epoch 8/500
# 33/33 [==============================] - ETA: 0s - loss: 0.8043 - auc: 0.8868
# Epoch 00008: val_auc did not improve from 0.76947
# 33/33 [==============================] - 53s 2s/step - loss: 0.8043 - auc: 0.8868 - val_loss: 1.3815 - val_auc: 0.7627
# Epoch 9/500
# 33/33 [==============================] - ETA: 0s - loss: 0.7535 - auc: 0.9001
# Epoch 00009: val_auc improved from 0.76947 to 0.77461, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 62s 2s/step - loss: 0.7535 - auc: 0.9001 - val_loss: 1.3340 - val_auc: 0.7746
# Epoch 10/500
# 33/33 [==============================] - ETA: 0s - loss: 0.7493 - auc: 0.9004
# Epoch 00010: val_auc improved from 0.77461 to 0.80998, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 62s 2s/step - loss: 0.7493 - auc: 0.9004 - val_loss: 1.1983 - val_auc: 0.8100
# Epoch 11/500
# 33/33 [==============================] - ETA: 0s - loss: 0.7330 - auc: 0.9046
# Epoch 00011: val_auc did not improve from 0.80998
# 33/33 [==============================] - 56s 2s/step - loss: 0.7330 - auc: 0.9046 - val_loss: 1.2931 - val_auc: 0.7926
# Epoch 12/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6999 - auc: 0.9127
# Epoch 00012: val_auc did not improve from 0.80998
# 33/33 [==============================] - 55s 2s/step - loss: 0.6999 - auc: 0.9127 - val_loss: 1.4979 - val_auc: 0.7805
# Epoch 13/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6917 - auc: 0.9142
# Epoch 00013: val_auc did not improve from 0.80998
# 33/33 [==============================] - 54s 2s/step - loss: 0.6917 - auc: 0.9142 - val_loss: 1.2825 - val_auc: 0.7910
# Epoch 14/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6742 - auc: 0.9186
# Epoch 00014: val_auc improved from 0.80998 to 0.81577, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 61s 2s/step - loss: 0.6742 - auc: 0.9186 - val_loss: 1.1750 - val_auc: 0.8158
# Epoch 15/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6573 - auc: 0.9228
# Epoch 00015: val_auc improved from 0.81577 to 0.81927, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 63s 2s/step - loss: 0.6573 - auc: 0.9228 - val_loss: 1.1282 - val_auc: 0.8193
# Epoch 16/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6789 - auc: 0.9175
# Epoch 00016: val_auc improved from 0.81927 to 0.83620, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 62s 2s/step - loss: 0.6789 - auc: 0.9175 - val_loss: 1.0966 - val_auc: 0.8362
# Epoch 17/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6429 - auc: 0.9248
# Epoch 00017: val_auc did not improve from 0.83620
# 33/33 [==============================] - 54s 2s/step - loss: 0.6429 - auc: 0.9248 - val_loss: 1.1893 - val_auc: 0.8209
# Epoch 18/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6169 - auc: 0.9309
# Epoch 00018: val_auc improved from 0.83620 to 0.84440, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 62s 2s/step - loss: 0.6169 - auc: 0.9309 - val_loss: 1.0748 - val_auc: 0.8444
# Epoch 19/500
# 32/33 [============================>.] - ETA: 1s - loss: 0.6006 - auc: 0.9346
# Epoch 00019: val_auc did not improve from 0.84440
# 33/33 [==============================] - 55s 2s/step - loss: 0.6013 - auc: 0.9345 - val_loss: 1.2270 - val_auc: 0.8154
# Epoch 20/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6229 - auc: 0.9295
# Epoch 00020: val_auc did not improve from 0.84440
# 33/33 [==============================] - 54s 2s/step - loss: 0.6229 - auc: 0.9295 - val_loss: 1.2674 - val_auc: 0.8195
# Epoch 21/500
# 32/33 [============================>.] - ETA: 1s - loss: 0.6099 - auc: 0.9327
# Epoch 00021: val_auc did not improve from 0.84440
# 33/33 [==============================] - 53s 2s/step - loss: 0.6100 - auc: 0.9326 - val_loss: 1.2134 - val_auc: 0.8076
# Epoch 22/500
# 33/33 [==============================] - ETA: 0s - loss: 0.6025 - auc: 0.9345
# Epoch 00022: val_auc did not improve from 0.84440
# 33/33 [==============================] - 54s 2s/step - loss: 0.6025 - auc: 0.9345 - val_loss: 1.1980 - val_auc: 0.8189
# Epoch 23/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5753 - auc: 0.9394
# Epoch 00023: val_auc did not improve from 0.84440
# 33/33 [==============================] - 54s 2s/step - loss: 0.5753 - auc: 0.9394 - val_loss: 1.1025 - val_auc: 0.8394
# Epoch 24/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5797 - auc: 0.9384
# Epoch 00024: val_auc did not improve from 0.84440
# 33/33 [==============================] - 55s 2s/step - loss: 0.5797 - auc: 0.9384 - val_loss: 1.1687 - val_auc: 0.8238
# Epoch 25/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5772 - auc: 0.9387
# Epoch 00025: val_auc did not improve from 0.84440
# 33/33 [==============================] - 53s 2s/step - loss: 0.5772 - auc: 0.9387 - val_loss: 1.1711 - val_auc: 0.8256
# Epoch 26/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5762 - auc: 0.9397
# Epoch 00026: val_auc did not improve from 0.84440
# 33/33 [==============================] - 54s 2s/step - loss: 0.5762 - auc: 0.9397 - val_loss: 1.1605 - val_auc: 0.8358
# Epoch 27/500
# 32/33 [============================>.] - ETA: 1s - loss: 0.5392 - auc: 0.9469
# Epoch 00027: val_auc improved from 0.84440 to 0.84664, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 61s 2s/step - loss: 0.5402 - auc: 0.9468 - val_loss: 1.0843 - val_auc: 0.8466
# Epoch 28/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5852 - auc: 0.9373
# Epoch 00028: val_auc did not improve from 0.84664
# 33/33 [==============================] - 55s 2s/step - loss: 0.5852 - auc: 0.9373 - val_loss: 1.1422 - val_auc: 0.8426
# Epoch 29/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5411 - auc: 0.9465
# Epoch 00029: val_auc did not improve from 0.84664
# 33/33 [==============================] - 54s 2s/step - loss: 0.5411 - auc: 0.9465 - val_loss: 1.2760 - val_auc: 0.8248
# Epoch 30/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5477 - auc: 0.9456
# Epoch 00030: val_auc did not improve from 0.84664
# 33/33 [==============================] - 54s 2s/step - loss: 0.5477 - auc: 0.9456 - val_loss: 1.2530 - val_auc: 0.8323
# Epoch 31/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5319 - auc: 0.9481
# Epoch 00031: val_auc did not improve from 0.84664
# 33/33 [==============================] - 55s 2s/step - loss: 0.5319 - auc: 0.9481 - val_loss: 1.1933 - val_auc: 0.8387
# Epoch 32/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5118 - auc: 0.9519
# Epoch 00032: val_auc did not improve from 0.84664
# 33/33 [==============================] - 54s 2s/step - loss: 0.5118 - auc: 0.9519 - val_loss: 1.2981 - val_auc: 0.8346
# Epoch 33/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5084 - auc: 0.9520
# Epoch 00033: val_auc improved from 0.84664 to 0.85730, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 63s 2s/step - loss: 0.5084 - auc: 0.9520 - val_loss: 1.1053 - val_auc: 0.8573
# Epoch 34/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5004 - auc: 0.9537
# Epoch 00034: val_auc improved from 0.85730 to 0.86789, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 62s 2s/step - loss: 0.5004 - auc: 0.9537 - val_loss: 1.0396 - val_auc: 0.8679
# Epoch 35/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4991 - auc: 0.9543
# Epoch 00035: val_auc did not improve from 0.86789
# 33/33 [==============================] - 55s 2s/step - loss: 0.4991 - auc: 0.9543 - val_loss: 1.1829 - val_auc: 0.8457
# Epoch 36/500
# 33/33 [==============================] - ETA: 0s - loss: 0.5425 - auc: 0.9466
# Epoch 00036: val_auc did not improve from 0.86789
# 33/33 [==============================] - 54s 2s/step - loss: 0.5425 - auc: 0.9466 - val_loss: 1.1550 - val_auc: 0.8439
# Epoch 37/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4877 - auc: 0.9560
# Epoch 00037: val_auc did not improve from 0.86789
# 33/33 [==============================] - 54s 2s/step - loss: 0.4877 - auc: 0.9560 - val_loss: 1.3471 - val_auc: 0.8375
# Epoch 38/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4903 - auc: 0.9558
# Epoch 00038: val_auc did not improve from 0.86789
# 33/33 [==============================] - 54s 2s/step - loss: 0.4903 - auc: 0.9558 - val_loss: 1.2541 - val_auc: 0.8467
# Epoch 39/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4908 - auc: 0.9554
# Epoch 00039: val_auc did not improve from 0.86789
# 33/33 [==============================] - 54s 2s/step - loss: 0.4908 - auc: 0.9554 - val_loss: 1.1217 - val_auc: 0.8597
# Epoch 40/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4972 - auc: 0.9545
# Epoch 00040: val_auc did not improve from 0.86789
# 33/33 [==============================] - 54s 2s/step - loss: 0.4972 - auc: 0.9545 - val_loss: 1.1101 - val_auc: 0.8616
# Epoch 41/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4981 - auc: 0.9544
# Epoch 00041: val_auc improved from 0.86789 to 0.87684, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 60s 2s/step - loss: 0.4981 - auc: 0.9544 - val_loss: 0.9464 - val_auc: 0.8768
# Epoch 42/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4955 - auc: 0.9550
# Epoch 00042: val_auc did not improve from 0.87684
# 33/33 [==============================] - 54s 2s/step - loss: 0.4955 - auc: 0.9550 - val_loss: 1.0660 - val_auc: 0.8617
# Epoch 43/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4758 - auc: 0.9580
# Epoch 00043: val_auc did not improve from 0.87684
# 33/33 [==============================] - 53s 2s/step - loss: 0.4758 - auc: 0.9580 - val_loss: 1.1756 - val_auc: 0.8521
# Epoch 44/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4835 - auc: 0.9574
# Epoch 00044: val_auc improved from 0.87684 to 0.87785, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 60s 2s/step - loss: 0.4835 - auc: 0.9574 - val_loss: 0.9776 - val_auc: 0.8778
# Epoch 45/500
# 32/33 [============================>.] - ETA: 1s - loss: 0.4693 - auc: 0.9590
# Epoch 00045: val_auc did not improve from 0.87785
# 33/33 [==============================] - 54s 2s/step - loss: 0.4691 - auc: 0.9590 - val_loss: 1.0740 - val_auc: 0.8672
# Epoch 46/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4954 - auc: 0.9548
# Epoch 00046: val_auc did not improve from 0.87785
# 33/33 [==============================] - 53s 2s/step - loss: 0.4954 - auc: 0.9548 - val_loss: 1.0753 - val_auc: 0.8661
# Epoch 47/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4642 - auc: 0.9603
# Epoch 00047: val_auc did not improve from 0.87785
# 33/33 [==============================] - 52s 2s/step - loss: 0.4642 - auc: 0.9603 - val_loss: 1.1000 - val_auc: 0.8597
# Epoch 48/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4412 - auc: 0.9642
# Epoch 00048: val_auc did not improve from 0.87785
# 33/33 [==============================] - 52s 2s/step - loss: 0.4412 - auc: 0.9642 - val_loss: 1.1553 - val_auc: 0.8542
# Epoch 49/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4686 - auc: 0.9596
# Epoch 00049: val_auc improved from 0.87785 to 0.88341, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 60s 2s/step - loss: 0.4686 - auc: 0.9596 - val_loss: 0.9666 - val_auc: 0.8834
# Epoch 50/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4523 - auc: 0.9624
# Epoch 00050: val_auc did not improve from 0.88341
# 33/33 [==============================] - 54s 2s/step - loss: 0.4523 - auc: 0.9624 - val_loss: 1.0838 - val_auc: 0.8688
# Epoch 51/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4421 - auc: 0.9636
# Epoch 00051: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4421 - auc: 0.9636 - val_loss: 1.1664 - val_auc: 0.8590
# Epoch 52/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4542 - auc: 0.9622
# Epoch 00052: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4542 - auc: 0.9622 - val_loss: 1.2028 - val_auc: 0.8540
# Epoch 53/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4338 - auc: 0.9652
# Epoch 00053: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4338 - auc: 0.9652 - val_loss: 1.2724 - val_auc: 0.8553
# Epoch 54/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4394 - auc: 0.9639
# Epoch 00054: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4394 - auc: 0.9639 - val_loss: 1.0633 - val_auc: 0.8717
# Epoch 55/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4481 - auc: 0.9631
# Epoch 00055: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4481 - auc: 0.9631 - val_loss: 1.0161 - val_auc: 0.8783
# Epoch 56/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4414 - auc: 0.9641
# Epoch 00056: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4414 - auc: 0.9641 - val_loss: 1.2716 - val_auc: 0.8522
# Epoch 57/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4119 - auc: 0.9683
# Epoch 00057: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4119 - auc: 0.9683 - val_loss: 1.2630 - val_auc: 0.8528
# Epoch 58/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4145 - auc: 0.9680
# Epoch 00058: val_auc did not improve from 0.88341
# 33/33 [==============================] - 54s 2s/step - loss: 0.4145 - auc: 0.9680 - val_loss: 1.2223 - val_auc: 0.8602
# Epoch 59/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4014 - auc: 0.9699
# Epoch 00059: val_auc did not improve from 0.88341
# 33/33 [==============================] - 54s 2s/step - loss: 0.4014 - auc: 0.9699 - val_loss: 1.2297 - val_auc: 0.8601
# Epoch 60/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4128 - auc: 0.9682
# Epoch 00060: val_auc did not improve from 0.88341
# 33/33 [==============================] - 53s 2s/step - loss: 0.4128 - auc: 0.9682 - val_loss: 1.1578 - val_auc: 0.8706
# Epoch 61/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4272 - auc: 0.9663
# Epoch 00061: val_auc improved from 0.88341 to 0.89000, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 61s 2s/step - loss: 0.4272 - auc: 0.9663 - val_loss: 0.9709 - val_auc: 0.8900
# Epoch 62/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4310 - auc: 0.9656
# Epoch 00062: val_auc did not improve from 0.89000
# 33/33 [==============================] - 55s 2s/step - loss: 0.4310 - auc: 0.9656 - val_loss: 0.9636 - val_auc: 0.8890
# Epoch 63/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4246 - auc: 0.9666
# Epoch 00063: val_auc did not improve from 0.89000
# 33/33 [==============================] - 54s 2s/step - loss: 0.4246 - auc: 0.9666 - val_loss: 0.9697 - val_auc: 0.8843
# Epoch 64/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4167 - auc: 0.9679
# Epoch 00064: val_auc did not improve from 0.89000
# 33/33 [==============================] - 53s 2s/step - loss: 0.4167 - auc: 0.9679 - val_loss: 1.1754 - val_auc: 0.8751
# Epoch 65/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4227 - auc: 0.9670
# Epoch 00065: val_auc did not improve from 0.89000
# 33/33 [==============================] - 53s 2s/step - loss: 0.4227 - auc: 0.9670 - val_loss: 1.2091 - val_auc: 0.8624
# Epoch 66/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4128 - auc: 0.9687
# Epoch 00066: val_auc did not improve from 0.89000
# 33/33 [==============================] - 53s 2s/step - loss: 0.4128 - auc: 0.9687 - val_loss: 1.1577 - val_auc: 0.8657
# Epoch 67/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4126 - auc: 0.9683
# Epoch 00067: val_auc improved from 0.89000 to 0.89444, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 60s 2s/step - loss: 0.4126 - auc: 0.9683 - val_loss: 0.9471 - val_auc: 0.8944
# Epoch 68/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3907 - auc: 0.9716
# Epoch 00068: val_auc did not improve from 0.89444
# 33/33 [==============================] - 53s 2s/step - loss: 0.3907 - auc: 0.9716 - val_loss: 1.1470 - val_auc: 0.8757
# Epoch 69/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4073 - auc: 0.9693
# Epoch 00069: val_auc did not improve from 0.89444
# 33/33 [==============================] - 52s 2s/step - loss: 0.4073 - auc: 0.9693 - val_loss: 1.0134 - val_auc: 0.8812
# Epoch 70/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4192 - auc: 0.9673
# Epoch 00070: val_auc did not improve from 0.89444
# 33/33 [==============================] - 52s 2s/step - loss: 0.4192 - auc: 0.9673 - val_loss: 0.9992 - val_auc: 0.8913
# Epoch 71/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4004 - auc: 0.9701
# Epoch 00071: val_auc did not improve from 0.89444
# 33/33 [==============================] - 53s 2s/step - loss: 0.4004 - auc: 0.9701 - val_loss: 1.1580 - val_auc: 0.8622
# Epoch 72/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3871 - auc: 0.9722
# Epoch 00072: val_auc did not improve from 0.89444
# 33/33 [==============================] - 53s 2s/step - loss: 0.3871 - auc: 0.9722 - val_loss: 1.0867 - val_auc: 0.8756
# Epoch 73/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3880 - auc: 0.9722
# Epoch 00073: val_auc did not improve from 0.89444
# 33/33 [==============================] - 53s 2s/step - loss: 0.3880 - auc: 0.9722 - val_loss: 1.0226 - val_auc: 0.8838
# Epoch 74/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3815 - auc: 0.9730
# Epoch 00074: val_auc did not improve from 0.89444
# 33/33 [==============================] - 53s 2s/step - loss: 0.3815 - auc: 0.9730 - val_loss: 1.1969 - val_auc: 0.8689
# Epoch 75/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3673 - auc: 0.9745
# Epoch 00075: val_auc did not improve from 0.89444
# 33/33 [==============================] - 65s 2s/step - loss: 0.3673 - auc: 0.9745 - val_loss: 1.1293 - val_auc: 0.8787
# Epoch 76/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3716 - auc: 0.9743
# Epoch 00076: val_auc improved from 0.89444 to 0.89568, saving model to ./best_weights.hdf5
# 33/33 [==============================] - 61s 2s/step - loss: 0.3716 - auc: 0.9743 - val_loss: 0.9661 - val_auc: 0.8957
# Epoch 77/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3570 - auc: 0.9760
# Epoch 00077: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3570 - auc: 0.9760 - val_loss: 1.0204 - val_auc: 0.8907
# Epoch 78/500
# 33/33 [==============================] - ETA: 0s - loss: 0.4221 - auc: 0.9676
# Epoch 00078: val_auc did not improve from 0.89568
# 33/33 [==============================] - 54s 2s/step - loss: 0.4221 - auc: 0.9676 - val_loss: 1.1764 - val_auc: 0.8658
# Epoch 79/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3726 - auc: 0.9741
# Epoch 00079: val_auc did not improve from 0.89568
# 33/33 [==============================] - 54s 2s/step - loss: 0.3726 - auc: 0.9741 - val_loss: 1.0996 - val_auc: 0.8758
# Epoch 80/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3709 - auc: 0.9743
# Epoch 00080: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3709 - auc: 0.9743 - val_loss: 1.0577 - val_auc: 0.8817
# Epoch 81/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3673 - auc: 0.9748
# Epoch 00081: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3673 - auc: 0.9748 - val_loss: 0.9859 - val_auc: 0.8897
# Epoch 82/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3534 - auc: 0.9766
# Epoch 00082: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3534 - auc: 0.9766 - val_loss: 1.1575 - val_auc: 0.8706
# Epoch 83/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3597 - auc: 0.9757
# Epoch 00083: val_auc did not improve from 0.89568
# 33/33 [==============================] - 54s 2s/step - loss: 0.3597 - auc: 0.9757 - val_loss: 1.1228 - val_auc: 0.8782
# Epoch 84/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3741 - auc: 0.9742
# Epoch 00084: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3741 - auc: 0.9742 - val_loss: 1.1001 - val_auc: 0.8820
# Epoch 85/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3473 - auc: 0.9771
# Epoch 00085: val_auc did not improve from 0.89568
# 33/33 [==============================] - 54s 2s/step - loss: 0.3473 - auc: 0.9771 - val_loss: 1.1782 - val_auc: 0.8628
# Epoch 86/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3816 - auc: 0.9728
# Epoch 00086: val_auc did not improve from 0.89568
# 33/33 [==============================] - 55s 2s/step - loss: 0.3816 - auc: 0.9728 - val_loss: 0.9602 - val_auc: 0.8938
# Epoch 87/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3432 - auc: 0.9780
# Epoch 00087: val_auc did not improve from 0.89568
# 33/33 [==============================] - 55s 2s/step - loss: 0.3432 - auc: 0.9780 - val_loss: 1.0201 - val_auc: 0.8828
# Epoch 88/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3509 - auc: 0.9769
# Epoch 00088: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3509 - auc: 0.9769 - val_loss: 1.1545 - val_auc: 0.8657
# Epoch 89/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3536 - auc: 0.9765
# Epoch 00089: val_auc did not improve from 0.89568
# 33/33 [==============================] - 54s 2s/step - loss: 0.3536 - auc: 0.9765 - val_loss: 1.1081 - val_auc: 0.8742
# Epoch 90/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3636 - auc: 0.9755
# Epoch 00090: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3636 - auc: 0.9755 - val_loss: 1.0635 - val_auc: 0.8806
# Epoch 91/500
# 33/33 [==============================] - ETA: 0s - loss: 0.3425 - auc: 0.9777
# Epoch 00091: val_auc did not improve from 0.89568
# 33/33 [==============================] - 53s 2s/step - loss: 0.3425 - auc: 0.9777 - val_loss: 1.0934 - val_auc: 0.8788
# Epoch 00091: early stopping

# %% [markdown]
# ### MODEL EVALUATION

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Test Data 

test_dataset  = test_datagen.flow_from_directory(directory = '../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test',
                                                 target_size = (224,224),
                                                 class_mode = 'categorical',
                                                 batch_size = 128)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
# Evaluating Loss and AUC

model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 4s 448ms/step - loss: 1.2377 - auc: 0.8870
# [1.2377309799194336, 0.8869889378547668]

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/NonDemented/26 (100).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict_classes(img)
probability = round(np.max(model.predict_proba(img)*100),2)

print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 99.93 % chances are there that the image is NonDemented

# %%
# Test Case 2: Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/MildDemented/26 (19).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict_classes(img)
probability = round(np.max(model.predict_proba(img)*100),2)

print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 97.86 % chances are there that the image is MildDemented

# %%
# Test Case 3: Moderate Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/ModerateDemented/27 (2).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict_classes(img)
probability = round(np.max(model.predict_proba(img)*100),2)

print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 86.79 % chances are there that the image is ModerateDemented

# %%
# Test Case 4: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('../input/alzheimers-dataset-4-class-of-images/Alzheimer_s Dataset/test/VeryMildDemented/26 (55).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = model.predict_classes(img)
probability = round(np.max(model.predict_proba(img)*100),2)

print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 91.97 % chances are there that the image is VeryMildDemented

# %% [markdown]
# Conclusion:
#
# So, we have finally built are deep learning model using DenseNet162 transfer learning algorithm and acheived and AUC-90%.
